# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-8ce9d5318002> in <module>
#       2
#       3 sys.path.append('../app')
# ----> 4 from utils import get_primary_prompt, get_edit_prompt
#
# ImportError: cannot import name 'get_primary_prompt' from 'utils' (../app/utils.py)

# %%
# % load_ext autoreload
# % autoreload 2
import sys
import pickle

sys.path.append('../app')
from format_query import QueryCreator

query_creator = QueryCreator()
data = pickle.load(open(query_creator.DATA_PATH, 'rb'))

# %%
print(data['edit_prefix'])
# Out:
# Input:
# ```
# name: Input
# type: GROUP
# node:
#   children:
#     0:
#       name: Modal Window
#       type: RECTANGLE
#       node:
#         color: '#ffffff'
#         opacity: 1
#         position:
#           x: 0
#           y: 0
#         cornerRadius: 0
#         width: 100
#         height: 59
#         strokeWeight: 1
#     1:
#       name: Cancel Text
#       type: TEXT
#       node:
#         characters: Continue?
#         fontSize: 8
#         fontWeight: 400
#         fontName:
#           family: Inter
#           style: Regular
#         position:
#           x: 29
#           y: 23
#         width: 40
#         height: 10
#     2:
#       name: Submit Button
#       type: RECTANGLE
#       node:
#         color: '#00ff00'
#         opacity: 1
#         position:
#           x: 66
#           y: 45
#         cornerRadius: 0
#         width: 30
#         height: 11
#         strokeWeight: 1
#     3:
#       name: Submit Text
#       type: TEXT
#       node:
# ...

# %%
edit_prompt = """ 'Input:\n```\nname: Input\ntype: GROUP\nnode:\n  children:\n    0:\n      name: Modal Window\n      type: RECTANGLE\n      node:\n        color: \'#ffffff\'\n        opacity: 1\n        position:\n          x: 0\n          y: 0\n        cornerRadius: 0\n        width: 100\n        height: 59\n        strokeWeight: 1\n    1:\n      name: Cancel Text\n      type: TEXT\n      node:\n        characters: Continue?\n        color: \'#000000\'\n        fontSize: 8\n        fontWeight: 400\n        position:\n          x: 0\n          y: 23\n        width: 100\n        height: 10\n        textAlignHorizontal: CENTER\n    2:\n      name: Submit Button\n      type: RECTANGLE\n      node:\n        color: \'#00ff00\'\n        opacity: 1\n        position:\n          x: 66\n          y: 45\n        cornerRadius: 0\n        width: 30\n        height: 11\n        strokeWeight: 1\n        dropShadow: 4\n    3:\n      name: Submit Text\n      type: TEXT\n      node:\n        characters: Submit\n       ...
"""
print(edit_prompt)
# Out:
#  'Input:
# ```
# name: Input
# type: GROUP
# node:
#   children:
#     0:
#       name: Modal Window
#       type: RECTANGLE
#       node:
#         color: '#ffffff'
#         opacity: 1
#         position:
#           x: 0
#           y: 0
#         cornerRadius: 0
#         width: 100
#         height: 59
#         strokeWeight: 1
#     1:
#       name: Cancel Text
#       type: TEXT
#       node:
#         characters: Continue?
#         color: '#000000'
#         fontSize: 8
#         fontWeight: 400
#         position:
#           x: 0
#           y: 23
#         width: 100
#         height: 10
#         textAlignHorizontal: CENTER
#     2:
#       name: Submit Button
#       type: RECTANGLE
#       node:
#         color: '#00ff00'
#         opacity: 1
#         position:
#           x: 66
#           y: 45
#         cornerRadius: 0
#         width: 30
#         height: 11
#         strokeWeight: 1
#         dropShadow: 4
#     3:
#       name: Submit Text
#       type: TEXT
# ...
